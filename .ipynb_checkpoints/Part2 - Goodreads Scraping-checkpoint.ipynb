# %% [markdown]
# # Most Read This Week on Goodreads

# %% [markdown]
# ### Text Mining Models and Algorithms: PSET 3
#
# ### Team members
#
# - Andrés Felipe Virgüez
# - Cristina Susanu
# - Manohar Gannavarapu
# - Mathias Schindler

# %% [markdown]
# # Introduction
#
# The goal of this notebook is show the code used to scrape data from Goodreads. According with wikipedia:
#
#    *Goodreads is an American social cataloging website and a subsidiary of Amazon that allows individuals to search its database of books, annotations, quotes, and reviews. Users can sign up and register books to generate library catalogs and reading lists. They can also create their own groups of book suggestions, surveys, polls, blogs, and discussions. The website's offices are located in San Francisco*
#
# Goodreads has a section in which shows the top 100 most readed books in the last week by genre. Our goal is to get the data for 29 genres (about 2900 books) that inclues author, book name, average rating, number of ratings, year of publication, and the text of the about the book.
#
# The pages that we scapre look as in the follow screenshot.

# %% [markdown]
# ![goodreds%20screenshot.png](attachment:goodreds%20screenshot.png)

# %% [markdown]
# ## Scraping

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import re

import time
import requests
from bs4 import BeautifulSoup

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 1: Get the list of genres

# %%
# Function
def get_all_genres():
    '''
    Function that retrieves all genres available on the goodreads' website
    '''
    url = "https://www.goodreads.com/genres/most_read/"
    genres = []
    page = requests.get(url)
    content = BeautifulSoup(page.text, "lxml")
    for item in content.find_all("a", class_="genreList__genreLink"):
        genres += item
    return list(dict.fromkeys(genres))
# Out:
# Requirement already satisfied: lxml in c:\users\x1\appdata\local\programs\python\python310\lib\site-packages (4.7.1)

# %%
# Get the list
print(get_all_genres())
genres = get_all_genres()[:29] # Only fist 29 (the last one is a link to other kind of page)
# Out:
# ['Art', 'Biography', 'Business', "Children's", 'Christian', 'Classics', 'Comics', 'Cookbooks', 'Ebooks', 'Fantasy', 'Fiction', 'Graphic Novels', 'Historical Fiction', 'History', 'Horror', 'Memoir', 'Music', 'Mystery', 'Nonfiction', 'Poetry', 'Psychology', 'Romance', 'Science', 'Science Fiction', 'Self Help', 'Sports', 'Thriller', 'Travel', 'Young Adult', 'More Genres']

# %% [markdown]
# ### Step 2: Function to get book details a specific genre

# %%
# Function

def get_book_details(genre):
    '''
    Function that retrieves all the details of the most read books in the current week
    '''
    # Request the webpage 
    url = "https://www.goodreads.com/genres/most_read/" + genre
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    
    top_class = soup.find_all("div", class_="leftAlignedImage bookBox")
    

    # Use of regex to extract the text fields we are interested in    
    book_url = [re.findall(r'href\=\"([\/a-zA-Z0-9\-]+)', str(i))[0] for i in top_class]    
    book_title = [re.findall(r'alt\=\"(.+)\" class', str(i))[0] for i in top_class]
    book_author = [re.findall(r'\/author\/show\/\d+\.([\_\d\w]+)\"\>', str(i).replace("\\", ""))[0] for i in top_class]
    book_rate = [re.findall(r'(\d\.\d{2}) avg rating', str(i).replace("\\", ""))[0] for i in top_class]
    book_ratings = [re.findall(r'avg rating &mdash; ([\d\,]+) ratings', str(i).replace("\\", ""))[0] for i in top_class]
    book_publisyear = [re.findall(r'&mdash; published (\d{4})n', str(i).replace("\\", ""))[0] for i in top_class]
    book_abstract = [re.findall(r'<span id="freeText\d+" style="display:none">(.+)\.?</span>n', str(i).replace("\\", "")) for i in top_class]
    
    # Create the data frame
    df = pd.DataFrame(list(zip(book_url, book_title, book_author, book_rate, book_ratings, book_publisyear, book_abstract)),
               columns =["Url", "Title", "Author", "Rate", "Ratings", "Year", "Abstract"])
    
    df['Genre'] = genre # add the genre to the dataframe
    df['Abstract'] = df['Abstract'].astype(str).replace("\[|\]", "", regex = True).replace("", np.nan)
    
    return df

# %%
# Testing the function 
print(genres[4])
test_df = get_book_details(genres[4])
print(test_df.shape)
test_df.head()
# Out:
# Christian
# (100, 8)
#                                                 Url  \
# 0  /book/show/56922594-the-stranger-in-the-lifeboat
# 1       /book/show/56552947-no-cure-for-being-human
# 2           /book/show/55867761-god-bless-this-mess
# 3          /book/show/57099601-once-upon-a-wardrobe
# 4             /book/show/57468098-a-stranger-s-game
#
#                                                Title          Author  Rate  \
# 0                       The Stranger in the Lifeboat     Mitch_Albom  4.19
# 1  No Cure for Being Human: And Other Truths I Ne...     Kate_Bowler  4.23
# 2  God Bless This Mess: Learning to Live and Love...    Hannah_Brown  3.85
# 3                               Once Upon a Wardrobe  Patti_Callahan  4.46
# 4                                  A Stranger's Game   Colleen_Coble  4.24
#
#   Ratings  Year                                           Abstract      Genre
# 0  18,414  2021  'What would happen if we called on God for hel...  Christian
# 1   7,806  2021  "n  The bestselling author of Everything Happe...  Christian
# 2   5,200  2021  "&quot;My life was a complete mess, and God bl...  Christian
# 3   5,414  2021  'From Patti Callahan, the bestselling author o...  Christian
# 4     599  2022  'A gripping new stand-alone novel from USA TOD...  Christian

# %% [markdown]
# ### Step 3: Looping over all the genres

# %%
# This loop extracts the data for all of the 29 genres and creates a single csv file
for i, genre in enumerate(genres):
    if i == 1:
        get_book_details(genre).to_csv('files/goodreads_scraped.csv', index=False)
    else:
        get_book_details(genre).to_csv('files/goodreads_scraped.csv', index=False, mode='a', header=False)

# %% [markdown]
# ### Bonus: Function to indicate the genre to scrape

# %%
# We had the idea of filtering by genre based on user input

def bonus_genre():
    """ This function ask for a Genre and create a file with the data for that genre """
    
    # Choose a genre
    genres = get_all_genres()
    for i in genres:
        print(i+ " /", end = " ")
    
    df_selected_genre = pd.DataFrame

    while True:
        try:
            selected = input("Please type a genre from the list below: ")
            if selected not in genres:
                raise Exception("sorry!")
        except Exception:
            print("Try again!")
            continue

        if selected == "All":
            if selected in genres:
                for genre in genres:
                    data.append(get_book_details(genre))
                    df_selected_genre = pd.concat(data)
                break
        else:
            get_book_details(selected).to_csv('files/goodreads_' + selected.replace(" ", "") + '.csv', index=False)
            
            break

# %%
bonus_genre()
# Out:
# Art / Biography / Business / Children's / Christian / Classics / Comics / Cookbooks / Ebooks / Fantasy / Fiction / Graphic Novels / Historical Fiction / History / Horror / Memoir / Music / Mystery / Nonfiction / Poetry / Psychology / Romance / Science / Science Fiction / Self Help / Sports / Thriller / Travel / Young Adult / More Genres / Please type a genre from the list below: Art

# %% [markdown]
# ## Checking  and exploring the data

# %%
df = pd.read_csv('files/goodreads_scraped.csv')
df.head()
# Out:
#                                         Url  \
# 0              /book/show/35133922-educated
# 1              /book/show/38746485-becoming
# 2  /book/show/50743767-between-two-kingdoms
# 3              /book/show/57094309-the-boys
# 4         /book/show/41721428-can-t-hurt-me
#
#                                                Title          Author  Rate  \
# 0                                           Educated   Tara_Westover  4.46
# 1                                           Becoming  Michelle_Obama  4.50
# 2  Between Two Kingdoms: A Memoir of a Life Inter...  Suleika_Jaouad  4.43
# 3        The Boys : A Memoir of Hollywood and Family      Ron_Howard  4.34
# 4  Can't Hurt Me: Master Your Mind and Defy the Odds   David_Goggins  4.36
#
#      Ratings  Year                                           Abstract  \
# 0  1,095,997  2018  "A newer edition of ISBN 9780399590504 can be ...
# 1    797,327  2018  'In a life filled with meaning and accomplishm...
# 2     31,550  2021  'A searing, deeply moving memoir of illness an...
# 3      5,346  2021  'Happy Days, The Andy Griffith Show, Gentle Be...
# 4    108,917  2018  "For David Goggins, childhood was a nightmare ...
#
#        Genre
# 0  Biography
# 1  Biography
# 2  Biography
# 3  Biography
# 4  Biography

# %%
# Check missing data
df.isnull().sum()
# Out:
# Url           0
# Title         0
# Author        0
# Rate          0
# Ratings       0
# Year          0
# Abstract    109
# Genre         0
# dtype: int64

# %%
# 109 books don't have the data of Abstract :(
df[df['Abstract'].isnull()].head(20)
# Out:
#                                                    Url  \
# 51                       /book/show/59649697-i-am-mine
# 113               /book/show/58505300-the-high-5-habit
# 170               /book/show/33517721-the-culture-code
# 407                   /book/show/48729531-spy-family-3
# 408                   /book/show/49252613-spy-family-4
# 410       /book/show/56304131-34-shingeki-no-kyojin-34
# 413       /book/show/51065933-30-shingeki-no-kyojin-30
# 420                   /book/show/56173529-demon-slayer
# 421             /book/show/52671507-2-kieta-hatsukoi-2
# 422                             /book/show/54702017-13
# 425                  /book/show/29237221-saga-volume-9
# 427      /book/show/35712936-5-yakusoku-no-neverland-5
# 432       /book/show/44300262-29-shingeki-no-kyojin-29
# 433                     /book/show/34963526-saga-vol-8
# 434                             /book/show/56269317-11
# 437        /book/show/57623339-asterix-and-the-griffin
# 438                              /book/show/54702009-9
# 440                             /book/show/55811132-10
# 442      /book/show/36481749-7-yakusoku-no-neverland-7
# 443  /book/show/55809807-the-sneaking-hiding-vibrat...
#
#                                                  Title            Author  \
# 51                                           I Am Mine      Eddie_Vedder
# 113  The High 5 Habit: Take Control of Your Life wi...       Mel_Robbins
# 170  The Culture Code: The Secrets of Highly Succes...      Daniel_Coyle
# 407                    SPY×FAMILY 3 (Spy x Family, #3)      Tatsuya_Endo
# 408                    SPY×FAMILY 4 (Spy x Family, #4)      Tatsuya_Endo
# 410  進撃の巨人 34 [Shingeki no Kyojin 34] (Attack on Ti...    Hajime_Isayama
# 413  進撃の巨人 30 [Shingeki no Kyojin 30] (Attack on Ti...    Hajime_Isayama
# 420    鬼滅の刃 外伝 [Demon Slayer: Kimetsu no Yaiba Gaiden]      Ryoji_Hirano
# 421   消えた初恋 2 [Kieta Hatsukoi 2] (My Love Mix-Up!, #2)   Wataru_Hinekure
# 422                      呪術廻戦 13 (Jujutsu Kaisen, #13)      Gege_Akutami
# 425                                     Saga, Volume 9   Brian_K_Vaughan
# 427              約束のネバーランド 5 [Yakusoku no Neverland 5]       Kaiu_Shirai
# 432  進撃の巨人 29 [Shingeki no Kyojin 29] (Attack on Ti...    Hajime_Isayama
# 433                                       Saga, Vol. 8   Brian_K_Vaughan
# 434                     チェンソーマン 11 (Chainsaw Man, #11)  Tatsuki_Fujimoto
# 437             Asterix and the Griffin (Asterix, #39)   Jean_Yves_Ferri
# 438                       チェンソーマン 9 (Chainsaw Man, #9)  Tatsuki_Fujimoto
# 440                     チェンソーマン 10 (Chainsaw Man, #10)  Tatsuki_Fujimoto
# 442              約束のネバーランド 7 [Yakusoku no Neverland 7]       Kaiu_Shirai
# 443  The Sneaking, Hiding, Vibrating Creature (Stra...     Nathan_W_Pyle
#
#      Rate Ratings  Year Abstract      Genre
# 51   4.10     922  2021      NaN  Biography
# 113  4.40   2,837  2021      NaN   Business
# 170  4.28  20,270  2017      NaN   Business
# 407  4.54   6,267  2020      NaN     Comics
# 408  4.55   4,960  2020      NaN     Comics
# 410  4.46   4,999  2021      NaN     Comics
# 413  4.70   6,425  2019      NaN     Comics
# 420  4.54     639  2020      NaN     Comics
# 421  4.42     473  2020      NaN     Comics
# 422  4.64   3,356  2020      NaN     Comics
# 425  4.57  25,638  2018      NaN     Comics
# 427  4.53   9,483  2017      NaN     Comics
# 432  4.59   6,289  2019      NaN     Comics
# 433  4.46  31,211  2017      NaN     Comics
# 434  4.49   2,866  2021      NaN     Comics
# 437  3.70   1,890  2021      NaN     Comics
# 438  4.59   3,203  2020      NaN     Comics
# 440  4.48   3,071  2021      NaN     Comics
# 442  4.42   7,353  2018      NaN     Comics
# 443  4.18   2,381  2021      NaN     Comics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2545 entries, 0 to 2544
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Url       2545 non-null   object
#  1   Title     2545 non-null   object
#  2   Author    2545 non-null   object
#  3   Rate      2545 non-null   float64
#  4   Ratings   2545 non-null   object
#  5   Year      2545 non-null   int64
#  6   Abstract  2436 non-null   object
#  7   Genre     2545 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 159.2+ KB

# %%
df['Ratings'] = df['Ratings'].replace('\,', '', regex=True).astype(int)

# %% [markdown]
# ### Exploring the data

# %%
# Top genres  (most rated)
top_genres = df.groupby('Genre')['Ratings'].sum().to_frame().sort_values('Ratings', ascending=False).reset_index()
top_genres
# Out:
#                  Genre   Ratings
# 0             Classics  71262998
# 1           Nonfiction  16029304
# 2              Fiction  10245883
# 3             Thriller   8313189
# 4              Romance   7958691
# 5   Historical Fiction   6647918
# 6              Mystery   6239064
# 7               Memoir   5501550
# 8              Fantasy   4167962
# 9            Self Help   3547353
# 10              Horror   3540206
# 11             History   3517500
# 12          Psychology   3363344
# 13         Young Adult   2961250
# 14           Biography   2923978
# 15            Business   2044147
# 16             Science   1931732
# 17     Science Fiction   1913141
# 18              Travel   1409483
# 19              Sports   1091659
# 20           Christian    895181
# 21              Poetry    687380
# 22              Comics    645136
# 23               Music    609576
# 24      Graphic Novels    579022
# 25           Cookbooks    188664

# %%
# Distribution plot of top genres
sns.kdeplot(x = 'Rate', hue = 'Genre' , data = df[df['Genre'].isin(list(top_genres.iloc[:5,0]))])
# Out:
# <AxesSubplot:xlabel='Rate', ylabel='Density'>

# %%
# Distribution plot of the genres with less ratings
sns.kdeplot(x = 'Rate', hue = 'Genre' , data = df[df['Genre'].isin(list(top_genres.iloc[-5:,0]))])
# Out:
# <AxesSubplot:xlabel='Rate', ylabel='Density'>

# %%
df['Abstract'].str.count(' ').add(1)
# Out:
# 0       281.0
# 1       243.0
# 2       425.0
# 3       276.0
# 4       148.0
#         ...
# 2540    113.0
# 2541    145.0
# 2542    179.0
# 2543    177.0
# 2544    155.0
# Name: Abstract, Length: 2545, dtype: float64

# %%
# More important, get some idea of what is in the text data

# Distribution of the number of words
df['text_n_words'] = df['Abstract'].str.count(' ').add(1)
sns.kdeplot(x = 'text_n_words', data = df)
# Out:
# <AxesSubplot:xlabel='text_n_words', ylabel='Density'>

# %%
# For some genres
sns.kdeplot(x = 'text_n_words', hue = 'Genre' , data = df[df['Genre'].isin(list(top_genres.iloc[:5,0]))])
# Out:
# <AxesSubplot:xlabel='text_n_words', ylabel='Density'>
